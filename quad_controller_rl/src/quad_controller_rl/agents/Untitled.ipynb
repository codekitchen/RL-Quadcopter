# %%
from ou_noise import OUNoise
import numpy as np
from matplotlib import pyplot as plt

# %%
s = np.random.randn() * 0.3
t = (0.6 + np.random.rand() * 0.2) * s
n1 = OUNoise(1, steps=20, theta=t, sigma=s)
plt.plot(np.array([n1.sample() for _ in range(500)]))
plt.show()
